# %%
# DATA LOADING
import pandas as pd
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")
validation = pd.read_csv("../data/submission.csv")
#test.head() to visualize if we want to
