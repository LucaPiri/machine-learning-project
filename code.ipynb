# %%
# Load data
import pandas as pd
df = pd.read_csv("test.csv")
df.head()
# Out:
#    Unnamed: 0  Unique Key            Created Date Agency  \
# 0           0    68610817  04/09/2026 11:45:46 AM    HPD
# 1           1    68569372  04/05/2026 10:15:15 AM    HPD
# 2           2    68628425  04/10/2026 08:44:52 AM   DSNY
# 3           3    68578580  04/06/2026 09:31:00 AM    DEP
# 4           4    68662147  04/14/2026 10:45:44 AM    HPD
#
#                                          Agency Name  \
# 0  Department of Housing Preservation and Develop...
# 1  Department of Housing Preservation and Develop...
# 2                           Department of Sanitation
# 3             Department of Environmental Protection
# 4  Department of Housing Preservation and Develop...
#
#   Problem (formerly Complaint Type) Problem Detail (formerly Descriptor)  \
# 0                    HEAT/HOT WATER                      ENTIRE BUILDING
# 1              UNSANITARY CONDITION                                PESTS
# 2                 Missed Collection                              Compost
# ...
